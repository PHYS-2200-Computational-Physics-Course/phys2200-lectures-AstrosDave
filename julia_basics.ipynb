# %% [markdown]
# # Julia Basics
# > adapted from https://github.com/mitmath/julia-mit,
# > https://algorithmsbook.com/validation/files/val.pdf#page=397

# %% [markdown]
# ## Julia as a calculator

# %%
3 + 4
# Out:
# 7

# %%
3 * 4
# Out:
# 12

# %%
3^4
# Out:
# 81

# %%
sin(3)
# Out:
# 0.1411200080598672

# %%
1 / (1 + sin(pi/4))
# Out:
# 0.585786437626905

# %% [markdown]
# ## Variables

# %%
x = 5

# %%
x
# Out:
# 5

# %%
x + 10
# Out:
# 15

# %% [markdown]
# ## Loops

# %%
for i in 1:5
    println(i)
end
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## Functions

# %%
function square(y)
    return y^2
end

# %%
square(7)
# Out:
# 49

# %% [markdown]
# ## Arrays

# %%
a = [1,2,3,4,5]
# Out:
# [1, 2, 3, 4, 5]

# %%
sum(a)
# Out:
# 15

# %% [markdown]
# ## Broadcasting

# %%
a .^ 2
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ## Random numbers

# %%
rand()
# Out:
# 0.5 ≤ rand() < 1.0 (example)
